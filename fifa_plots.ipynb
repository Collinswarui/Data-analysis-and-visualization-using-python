# %%
import pandas as pd 
import numpy as np
import seaborn as sns
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
df=pd.read_csv('/home/anonymous/datasets/fifa.csv')

# %%
df.head()
# Out:
#          Date   ARG  BRA   ESP   FRA  GER  ITA
# 0  1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1  1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 2  1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0
# 3  1993-11-19   9.0  4.0   7.0  15.0  3.0  1.0
# 4  1993-12-23   8.0  3.0   5.0  15.0  1.0  2.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 286 entries, 0 to 285
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    286 non-null    object
#  1   ARG     286 non-null    float64
#  2   BRA     286 non-null    float64
#  3   ESP     286 non-null    float64
#  4   FRA     286 non-null    float64
#  5   GER     286 non-null    float64
#  6   ITA     286 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 15.8+ KB

# %%
df.describe()
# Out:
#               ARG         BRA         ESP         FRA         GER         ITA
# count  286.000000  286.000000  286.000000  286.000000  286.000000  286.000000
# mean     5.454545    3.171329    5.321678    8.958042    5.104895    8.353147
# std      4.012659    3.620897    3.908787    6.822948    4.354813    4.514822
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      3.000000    1.000000    2.000000    3.000000    2.000000    4.000000
# 50%      5.000000    1.500000    5.000000    7.000000    4.000000    8.000000
# 75%      7.000000    4.000000    8.000000   15.000000    5.000000   12.000000
# max     24.000000   22.000000   25.000000   27.000000   22.000000   20.000000

# %%
t=df[['ARG','BRA','ESP','FRA','GER','ITA']]
print(t)
# Out:
#       ARG  BRA   ESP   FRA  GER   ITA
# 0     5.0  8.0  13.0  12.0  1.0   2.0
# 1    12.0  1.0  14.0   7.0  5.0   2.0
# 2     9.0  1.0   7.0  14.0  4.0   3.0
# 3     9.0  4.0   7.0  15.0  3.0   1.0
# 4     8.0  3.0   5.0  15.0  1.0   2.0
# ..    ...  ...   ...   ...  ...   ...
# 281   4.0  2.0   6.0   9.0  1.0  14.0
# 282   4.0  2.0   6.0   9.0  1.0  14.0
# 283   5.0  2.0   8.0   7.0  1.0  20.0
# 284   5.0  2.0   8.0   7.0  1.0  20.0
# 285   5.0  2.0  10.0   7.0  1.0  19.0
#
# [286 rows x 6 columns]

# %%
z=t.sample(frac=0.025)
print(z)
# Out:
#       ARG  BRA   ESP   FRA   GER   ITA
# 271   2.0  1.0  10.0   6.0   3.0  12.0
# 84    3.0  2.0   6.0   1.0   8.0   4.0
# 40   13.0  1.0   2.0  11.0   4.0   8.0
# 99    5.0  1.0   3.0   2.0   4.0  11.0
# 21    9.0  1.0   6.0  20.0   4.0   2.0
# 120  11.0  1.0   3.0   2.0  12.0   9.0
# 182   6.0  1.0   2.0   9.0   5.0   4.0

# %%
sns.heatmap(z, annot=True)
# Out:
# <AxesSubplot: >

# %%
sns.lineplot(z)
# Out:
# <AxesSubplot: >

# %%
sns.kdeplot(z,fill=True)
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
sns.kdeplot(t, fill=True)
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
sns.scatterplot(t)
# Out:
# <AxesSubplot: >

# %%
sns.histplot(z)
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
sns.barplot(z)
# Out:
# <AxesSubplot: >
