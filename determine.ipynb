# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
import numpy as np
df = pd.read_csv('/home/anonymous/Downloads/fortune500.csv')
# Out:
# Setup Complete

# %%
df.head()
# Out:
#    Year  Rank           Company Revenue (in millions) Profit (in millions)
# 0  1955     1    General Motors                9823.5                  806
# 1  1955     2       Exxon Mobil                5661.4                584.8
# 2  1955     3        U.S. Steel                3250.4                195.4
# 3  1955     4  General Electric                2959.1                212.6
# 4  1955     5            Esmark                2510.8                 19.1

# %%
df['Company'].dropna()
# Out:
# 0          General Motors
# 1             Exxon Mobil
# 2              U.S. Steel
# 3        General Electric
# 4                  Esmark
#                ...
# 29495             Tellabs
# 29496         Administaff
# 29497     Sanderson Farms
# 29498     MGIC Investment
# 29499    Career Education
# Name: Company, Length: 29500, dtype: object

# %%
df.head(100)
df.tail(50)
# Out:
#        Year  Rank                         Company Revenue (in millions)  \
# 29450  2009   951                          Xilinx              1,841.40
# 29451  2009   952                   Westar Energy              1,839.00
# 29452  2009   953                Urban Outfitters              1,834.60
# 29453  2009   954                   Arkansas Best              1,833.10
# 29454  2009   955                  Curtiss-Wright              1,830.10
# 29455  2009   956                         Covance              1,827.10
# 29456  2009   957            Wendy's/Arby's Group              1,822.80
# 29457  2009   958                         Perrigo              1,822.10
# 29458  2009   959                    Radian Group              1,808.00
# 29459  2009   960                    E.W. Scripps              1,806.20
# 29460  2009   961                   Michael Foods              1,804.40
# 29461  2009   962           Cypress Semiconductor              1,803.00
# ...

# %%
df['Year'].describe()
# Out:
# count    29500.000000
# mean      1983.728814
# std         16.616417
# min       1955.000000
# 25%       1969.000000
# 50%       1984.000000
# 75%       1999.000000
# max       2009.000000
# Name: Year, dtype: float64

# %%
#equation is f(x)=ax+b
X=df['Rank']
Y=df['Year']


slope_intercept=np.polyfit(X,Y,1)
print(slope_intercept)
# Out:
# [2.19962720e-02 1.97747312e+03]

# %%
#substitute the equation f(x)=2.19962720e-02(x)+1.97747312e+03

def my_Function(X):
    return((2.19962720e-02*X)+1.97747312e+03)
print(my_Function(24))
# Out:
# 1978.001030528

# %%
df=df.rename(columns={"Profit (in millions)":"profit"})

# %%
df.head()
# Out:
#    Year  Rank           Company Revenue (in millions) profit
# 0  1955     1    General Motors                9823.5    806
# 1  1955     2       Exxon Mobil                5661.4  584.8
# 2  1955     3        U.S. Steel                3250.4  195.4
# 3  1955     4  General Electric                2959.1  212.6
# 4  1955     5            Esmark                2510.8   19.1

# %%
fd.head()
# Out:
#    Year  Rank           Company Revenue (in millions) profit
# 0  1955     1    General Motors                9823.5    806
# 1  1955     2       Exxon Mobil                5661.4  584.8
# 2  1955     3        U.S. Steel                3250.4  195.4
# 3  1955     4  General Electric                2959.1  212.6
# 4  1955     5            Esmark                2510.8   19.1

# %%
df.groupby('Company').profit.agg([len,min,max])
# Out:
#                  len       min    max
# Company
# 3Com               5      30.2  674.3
# 3M                55     102.3    976
# A-T-O              4      10.7    9.2
# A. Schulman        9        18   43.8
# A.G. Edwards       3     186.5  331.4
# ...              ...       ...    ...
# Zimmer Holdings    4     732.5  848.6
# Zions Bancorp      2     480.1  583.1
# Zions Bancorp.     2    -266.3  493.7
# Zurn Industries    1      28.3   28.3
# eBay               4  1,779.50  348.3
#
# [2588 rows x 3 columns]

# %%
fd[pd.isnull(fd.profit)]
# Out:
# Empty DataFrame
# Columns: [Year, Rank, Company, Revenue (in millions), profit]
# Index: []

# %%
fd.dtypes
# Out:
# Year                      int64
# Rank                      int64
# Company                  object
# Revenue (in millions)    object
# profit                   object
# dtype: object

# %%
fd.Year.dtype
# Out:
# dtype('int64')

# %%
fd[pd.notnull(fd.profit)]
# Out:
#        Year  Rank           Company Revenue (in millions)  profit
# 0      1955     1    General Motors                9823.5     806
# 1      1955     2       Exxon Mobil                5661.4   584.8
# 2      1955     3        U.S. Steel                3250.4   195.4
# 3      1955     4  General Electric                2959.1   212.6
# 4      1955     5            Esmark                2510.8    19.1
# ...     ...   ...               ...                   ...     ...
# 29495  2009   996           Tellabs              1,729.00  -930.1
# 29496  2009   997       Administaff              1,724.40    45.8
# 29497  2009   998   Sanderson Farms              1,723.60   -43.1
# 29498  2009   999   MGIC Investment              1,721.50  -518.9
# 29499  2009  1000  Career Education              1,720.80    60.1
#
# [29500 rows x 5 columns]

# %%
df.Company=df.Company.replace("General Motors","G Motors")

# %%
df
# Out:
#        Year  Rank           Company Revenue (in millions) Profit (in millions)
# 0      1955     1          G Motors                9823.5                  806
# 1      1955     2       Exxon Mobil                5661.4                584.8
# 2      1955     3        U.S. Steel                3250.4                195.4
# 3      1955     4  General Electric                2959.1                212.6
# 4      1955     5            Esmark                2510.8                 19.1
# ...     ...   ...               ...                   ...                  ...
# 29495  2009   996           Tellabs              1,729.00               -930.1
# 29496  2009   997       Administaff              1,724.40                 45.8
# 29497  2009   998   Sanderson Farms              1,723.60                -43.1
# 29498  2009   999   MGIC Investment              1,721.50               -518.9
# 29499  2009  1000  Career Education              1,720.80                 60.1
#
# ...

# %%
df=df.rename(columns={"Revenue (in millions)":"revenue"})

# %%
df.head()
# Out:
#    Year  Rank           Company Revenue (in millions) Profit (in millions)
# 0  1955     1          G Motors                9823.5                  806
# 1  1955     2       Exxon Mobil                5661.4                584.8
# 2  1955     3        U.S. Steel                3250.4                195.4
# 3  1955     4  General Electric                2959.1                212.6
# 4  1955     5            Esmark                2510.8                 19.1

# %%
plt.figure(figsize=(16,6))
sns.lineplot(data=df)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16,6))
sns.countplot(data=df)
# Out:
# <AxesSubplot:ylabel='count'>

# %%
plt.figure(figsize=(16,6))
sns.boxplot(data=df)
plt.grid()

# %%
plt.figure(figsize=(16,10))
sns.scatterplot(data=df)
plt.grid()
