# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/home/anonymous/datasets/fifa.csv')

# %%
df
# Out:
#            Date   ARG  BRA   ESP   FRA  GER   ITA
# 0    1993-08-08   5.0  8.0  13.0  12.0  1.0   2.0
# 1    1993-09-23  12.0  1.0  14.0   7.0  5.0   2.0
# 2    1993-10-22   9.0  1.0   7.0  14.0  4.0   3.0
# 3    1993-11-19   9.0  4.0   7.0  15.0  3.0   1.0
# 4    1993-12-23   8.0  3.0   5.0  15.0  1.0   2.0
# ..          ...   ...  ...   ...   ...  ...   ...
# 281  2018-02-15   4.0  2.0   6.0   9.0  1.0  14.0
# 282  2018-03-15   4.0  2.0   6.0   9.0  1.0  14.0
# 283  2018-04-12   5.0  2.0   8.0   7.0  1.0  20.0
# 284  2018-05-17   5.0  2.0   8.0   7.0  1.0  20.0
# 285  2018-06-07   5.0  2.0  10.0   7.0  1.0  19.0
#
# [286 rows x 7 columns]

# %%
plt.figure(figsize=(15,6))
plt.title('Fifa Rankings of top 6 teams')
sns.lineplot(df)
# Out:
# <AxesSubplot: title={'center': 'Fifa Rankings of top 6 teams'}>

# %%
plt.figure(figsize=(15,6))
plt.title('Fifa Rankings of top 6 teams')
sns.lineplot(df['BRA'],label="BRA")
sns.lineplot(df['FRA'],label="FRA")
plt.xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %%
df.max()
# Out:
# Date    2018-06-07
# ARG           24.0
# BRA           22.0
# ESP           25.0
# FRA           27.0
# GER           22.0
# ITA           20.0
# dtype: object

# %%
sns.barplot(df)
# Out:
# <AxesSubplot: >

# %%
sns.barplot(x=df.index, y=df['FRA'])
# Out:
# <AxesSubplot: ylabel='FRA'>

# %%
h=df.sample(frac=0.025)

# %%
sns.barplot(h)
# Out:
# <AxesSubplot: >

# %%
sns.barplot(x=h.index, y=h['ITA'])
# Out:
# <AxesSubplot: ylabel='ITA'>

# %%
df['Date'].dropna()
# Out:
# 0      1993-08-08
# 1      1993-09-23
# 2      1993-10-22
# 3      1993-11-19
# 4      1993-12-23
#           ...
# 281    2018-02-15
# 282    2018-03-15
# 283    2018-04-12
# 284    2018-05-17
# 285    2018-06-07
# Name: Date, Length: 286, dtype: object

# %%
df
# Out:
#            Date   ARG  BRA   ESP   FRA  GER   ITA
# 0    1993-08-08   5.0  8.0  13.0  12.0  1.0   2.0
# 1    1993-09-23  12.0  1.0  14.0   7.0  5.0   2.0
# 2    1993-10-22   9.0  1.0   7.0  14.0  4.0   3.0
# 3    1993-11-19   9.0  4.0   7.0  15.0  3.0   1.0
# 4    1993-12-23   8.0  3.0   5.0  15.0  1.0   2.0
# ..          ...   ...  ...   ...   ...  ...   ...
# 281  2018-02-15   4.0  2.0   6.0   9.0  1.0  14.0
# 282  2018-03-15   4.0  2.0   6.0   9.0  1.0  14.0
# 283  2018-04-12   5.0  2.0   8.0   7.0  1.0  20.0
# 284  2018-05-17   5.0  2.0   8.0   7.0  1.0  20.0
# 285  2018-06-07   5.0  2.0  10.0   7.0  1.0  19.0
#
# [286 rows x 7 columns]

# %%
del df['Date']
df.to_csv('fifa.csv', index=False)

# %%
df
# Out:
#       ARG  BRA   ESP   FRA  GER   ITA
# 0     5.0  8.0  13.0  12.0  1.0   2.0
# 1    12.0  1.0  14.0   7.0  5.0   2.0
# 2     9.0  1.0   7.0  14.0  4.0   3.0
# 3     9.0  4.0   7.0  15.0  3.0   1.0
# 4     8.0  3.0   5.0  15.0  1.0   2.0
# ..    ...  ...   ...   ...  ...   ...
# 281   4.0  2.0   6.0   9.0  1.0  14.0
# 282   4.0  2.0   6.0   9.0  1.0  14.0
# 283   5.0  2.0   8.0   7.0  1.0  20.0
# 284   5.0  2.0   8.0   7.0  1.0  20.0
# 285   5.0  2.0  10.0   7.0  1.0  19.0
#
# [286 rows x 6 columns]

# %%
t=df.sample(frac=0.025)

# %%
sns.heatmap(t[['ITA','BRA']], annot=True)
# Out:
# <AxesSubplot: >

# %%
sns.scatterplot(df)
# Out:
# <AxesSubplot: >

# %%
sns.scatterplot(t)
# Out:
# <AxesSubplot: >

# %%
sns.histplot(t)
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
plt.title('Fifa distributions')
sns.kdeplot(df,fill=True)
# Out:
# <AxesSubplot: title={'center': 'Fifa distributions'}, ylabel='Density'>
